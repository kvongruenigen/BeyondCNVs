# %%
#os.getcwd() #'/Users/kayvongrunigen/Desktop/Project/dev'
os.chdir('/Users/kayvongrunigen/.local/lib/python3.10/site-packages/bycon/')

# %%
from bycon import *

# %%
mapfile = read_tsv_to_dictlist('../temp/mappingfile.tsv')

# %%
bios_ids = set()
empty = 0
for v in mapfile[0]: 
    bs_id = v.get("biosample_id", False)
    if bs_id == '' :
        empty += 1
    
empty
# Out:
# 38553

# %%
bios_ids
# Out:
# {'',
#  'pgxbs-kftvi8wv',
#  'pgxbs-kftvi0no',
#  'pgxbs-kftvhn79',
#  'pgxbs-kftvi8kr',
#  'pgxbs-kftvhlns',
#  'pgxbs-kftvhiyc',
#  'pgxbs-kftvhq77',
#  'pgxbs-kftvi049',
#  'pgxbs-kftvi59o',
#  'pgxbs-kftvi1lv',
#  'pgxbs-kftvhqm2',
#  'pgxbs-kftvhx7e',
#  'pgxbs-kftvi4aj',
#  'pgxbs-kftvi1gs',
#  'pgxbs-kftvhttl',
#  'pgxbs-kftvi1lx',
#  'pgxbs-kftvhz63',
#  'pgxbs-kftvi5yj',
#  'pgxbs-kftvhx9r',
#  'pgxbs-kftvhkmg',
#  'pgxbs-kftvi0ol',
#  'pgxbs-kftvi7il',
#  'pgxbs-kftvhs05',
#  'pgxbs-kftvhlv9',
#  'pgxbs-kftvhtn5',
#  'pgxbs-kftvhzvz',
#  'pgxbs-kftvhspb',
#  'pgxbs-kftvi495',
#  'pgxbs-kftvhknt',
#  'pgxbs-kftvi8zp',
#  'pgxbs-kftvi1fn',
#  'pgxbs-kftvhztn',
#  'pgxbs-kftvhs5y',
#  'pgxbs-kftvi2d4',
#  'pgxbs-kftvhmyb',
#  'pgxbs-kftvi9gc',
#  'pgxbs-kftvi53g',
#  'pgxbs-kftvi31u',
#  'pgxbs-kftvhvwd',
#  'pgxbs-kftvi55r',
#  'pgxbs-kftvhst1',
#  'pgxbs-kftvhw11',
#  'pgxbs-kftvhxpv',
#  'pgxbs-kftvi7tw',
#  'pgxbs-kftvhx8y',
#  'pgxbs-kftvhxau',
#  'pgxbs-kftvhrkz',
# ...

# %%
# Working copy updated version
import re, json, yaml
from os import path, environ, pardir
import sys, datetime

from bycon import *

# Connect to MongoDB
from pymongo import MongoClient
client = MongoClient()
db = client.progenetix
bs = db.biosamples
var_coll = db.variants

variants, fieldnames = read_tsv_to_dictlist('/Users/kayvongrunigen/Desktop/Project/temp/mappingfile.tsv') #########

var_no = len(variants)
up_v_no = 0

delBiosVars = input("Delete variants from matched biosamples before insertion?\n(y|N): ")

bios_ids = set()
for c, v in enumerate(variants):
    bs_id = v.get("biosample_id", False)
    if not bs_id:
        print("¡¡¡ The `biosample_id` parameter is required for variant assignment !!!")
        exit()
    if not "pgxbs-" in bs_id:
        print("¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!")
        exit()
    bios_ids.add(bs_id)

print("=> The variants file contains {} variants from {} samples.".format(var_no, len(bios_ids)))
proceed = input("Do you want to continue to update database **{}**?\n(Y|n): ".format('progenetix'))
if "n" in proceed.lower():
    exit()

if "y" in delBiosVars.lower():
    for b_del in bios_ids:
        v_d = var_coll.delete_many({"biosample_id": b_del})
        print("==>> deleted {} variants from {}".format(v_d.deleted_count, b_del))

v_proto = object_instance_from_schema_name(byc, "pgxVariant", "") #pgxVariant

for c, v in enumerate(variants, 1):

    bs_id = v.get("biosample_id", False)

    # TODO: variant prototype from schema
    insert_v = v_proto.copy()

    # TODO: This is a bit of a double definition; disentangle ...
    insert_v.update( {
        "legacy_id": v.get("variant_id", f'pgxvar-{c:09d}'),
        "biosample_id": bs_id,            
        "callset_id": v.get("callset_id", re.sub("pgxbs-", "pgxcs-", bs_id)),
        "individual_id": v.get("individual_id", re.sub("pgxbs-", "pgxind-", bs_id))
    })

    insert_v = import_datatable_dict_line(byc, insert_v, fieldnames, v, "variant")
    insert_v.update({
        "variant_internal_id": variant_create_digest(insert_v, byc),
        "updated": datetime.datetime.now().isoformat()
    })

    if not byc["test_mode"]:
        vid = var_coll.insert_one( insert_v  ).inserted_id
        vstr = 'pgxvar-'+str(vid)
        var_coll.update_one({'_id':vid},{'$set':{ 'id':vstr }})
        print("=> inserted {}".format(vstr))
    else:
        prjsonnice(insert_v)

exit()
# Out:
# Delete variants from matched biosamples before insertion?
# (y|N): N
# ¡¡¡ The `biosample_id` parameter is required for variant assignment !!!
# ¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!
# ¡¡¡ The `biosample_id` parameter is required for variant assignment !!!
# ¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!
# ¡¡¡ The `biosample_id` parameter is required for variant assignment !!!
# ¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!
# ¡¡¡ The `biosample_id` parameter is required for variant assignment !!!
# ¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!
# ¡¡¡ The `biosample_id` parameter is required for variant assignment !!!
# ¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!
# ¡¡¡ The `biosample_id` parameter is required for variant assignment !!!
# ¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!
# ¡¡¡ The `biosample_id` parameter is required for variant assignment !!!
# ...

# %%
# Function 'object_instance_from_schema_name()' gives problems
# s_f_p = ....bycon/lib/../schemas/models/json/progenetix-database-schemas/pgxVariant.json

root_def = RefDict(s_f_p)
exclude_keys = [ "examples" ] #"format",
s = materialize(root_def, exclude_keys=exclude_keys) ### Raises problems - because of root_def

# Path not found
# /Users/kayvongrunigen/.local/lib/python3.10/site-packages/bycon/lib/../schemas/models/json/
# progenetix-database-schemas/../common/ontologyTerm.json#/properties

# but should be:
# progenetix-database-schemas/../progenetix-model/common/ontologyTerm.json#/properties

# pprint.pprint(root_def)
{'$id': 'https://progenetix.org/services/schemas/pgxVariant/v2022-03-29',
 '$schema': 'https://json-schema.org/draft/2020-12/schema',
 'additionalProperties': True,
 'definitions': {'Location': {'properties': {'interval': {'$ref': '#/definitions/SequenceInterval/properties'},
                                             'sequenceId': {'type': 'string'},
                                             'type': {'const': 'SequenceLocation'}},
                              'type': 'object'},
                 'PointPosition': {'properties': {'type': {'const': 'Number'},
                                                  'value': {'type': 'integer'}},
                                   'type': 'object'},
                 'SequenceInterval': {'properties': {'end': {'$ref': '#/definitions/PointPosition/properties'},
                                                     'start': {'$ref': '#/definitions/PointPosition/properties'},
                                                     'type': {'const': 'SequenceInterval'}},
                                      'type': 'object'},
                 'SequenceState': {'properties': {'const': 'LiteralSequenceExpression'},
                                   'sequence': {'type': 'string'},
                                   'type': 'object'}},
 'description': 'Schema for a genomic variant in Progenetix collections.',
 'properties': {'alternateBases': {'pattern': '^([ACGTUNRYSWKMBDHV\\-\\.]*)$',
                                   'type': 'string'},
                'biosampleId': {'type': 'string'},
                'callsetId': {'type': 'string'},
                'end': {'type': 'integer'},
                'id': {'type': 'string'},
                'individualId': {'type': 'string'},
                'info': {'type': 'object'},
                'location': {'$ref': '#/definitions/Location/properties'},
                'referenceBases': {'pattern': '^([ACGTUNRYSWKMBDHV\\-\\.]*)$',
                                   'type': 'string'},
                'relativeCopyClass': {'enum': ['copy neutral',
                                               'partial loss',
                                               'complete loss',
                                               'low-level gain',
                                               'high-level gain'],
                                      'type': 'string'},
                'start': {'type': 'integer'},
                'state': {'$ref': '#/definitions/SequenceState/properties'},
                'type': {'enum': ['Allele', 'RelativeCopyNumber'],
                         'type': 'string'},
                'updated': {'examples': ['2020-09-10T17:44:10.170Z'],
                            'format': 'date-time',
                            'type': 'string'},
                'variantInternalId': {'type': 'string'},
#                'variantState': {'$ref': '../common/ontologyTerm.json#/properties'}, -> could be problem?
                'variantType': {'type': 'string'}},
 'required': ['variantInternalId', 'variantType'],
 'title': 'Progenetix Variant',
 'type': 'object'}

# %%
schema_name = 'pgxVariant'
item = ''
ext = 'json'


b_p_m = byc["beacon_mappings"]["default_schema_from_model"]

schema_name = b_p_m.get(schema_name, schema_name)

config = byc["config"]

for s_p in config["schema_paths"]["items"]:

    p = path.join( pkg_path, *config["schemas_root"], *s_p )

    s_ds = [ d.name for d in scandir(p) if d.is_dir() ]
    if schema_name in s_ds:
        s_f_p = path.join( p, schema_name, "defaultSchema."+ext )


    s_fs = [ f.name for f in scandir(p) if f.is_file() ]
    s_fs = [ f for f in s_fs if f.endswith( ext ) ]
    s_fs = [ f for f in s_fs if not f.startswith("_") ]

    for s_f in s_fs:

        f_name = path.splitext( s_f )[0]
        # print(schema_name, f_name)

        if f_name == schema_name:
            s_f_p = path.join( p, s_f )


if byc["debug_mode"] is True:
    print(schema_name, s_f_p)

if not s_f_p is False:
    if len(item) > 1:
        s_f_p = s_f_p+"#/"+item
    print(s_f_p)    # bycon/lib/../schemas/models/json/progenetix-database-schemas/pgxVariant.json
    root_def = RefDict(s_f_p)
    pprint.pprint(root_def)
#                'variantState': {'$ref': '../common/ontologyTerm.json#/properties'}, -> could be problem?

    exclude_keys = [ "examples" ] #"format",
#     s = materialize(root_def, exclude_keys=exclude_keys)
#     assert isinstance(s, dict)

# s_f = s
# print(s_f)
# Out:
# /Users/kayvongrunigen/.local/lib/python3.10/site-packages/bycon/lib/../schemas/models/json/progenetix-database-schemas/pgxVariant.json
# {'$id': 'https://progenetix.org/services/schemas/pgxVariant/v2022-03-29',
#  '$schema': 'https://json-schema.org/draft/2020-12/schema',
#  'additionalProperties': True,
#  'definitions': {'Location': {'properties': {'interval': {'$ref': '#/definitions/SequenceInterval/properties'},
#                                              'sequenceId': {'type': 'string'},
#                                              'type': {'const': 'SequenceLocation'}},
#                               'type': 'object'},
#                  'PointPosition': {'properties': {'type': {'const': 'Number'},
#                                                   'value': {'type': 'integer'}},
#                                    'type': 'object'},
#                  'SequenceInterval': {'properties': {'end': {'$ref': '#/definitions/PointPosition/properties'},
# ...

# %%
v_proto = object_instance_from_schema_name(byc, "pgxVariant", "")
v_proto
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/homebrew/mambaforge/lib/python3.10/urllib/request.py:1505, in FileHandler.open_local_file(self, req)
#    1504 try:
# -> 1505     stats = os.stat(localfile)
#    1506     size = stats.st_size
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/kayvongrunigen/.local/lib/python3.10/site-packages/bycon/lib/../schemas/models/json/progenetix-database-schemas/../common/ontologyTerm.json'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/json_ref_dict/loader.py:99, in default_get_document(base_uri)
#      98 try:
# ---> 99     return _read_document_content(base_uri)
#     100 except Exception as exc:
#
# ...

# %%
# Updated version 24/5/23

import re, json, yaml
from os import path, environ, pardir
import sys, datetime

from bycon import *

"""
"""

################################################################################
################################################################################
################################################################################

def main():

    variantsInserter()

################################################################################

def variantsInserter():

    initialize_bycon_service(byc)
    parse_variant_parameters(byc)
    select_dataset_ids(byc)

    if len(byc["dataset_ids"]) != 1:
        print("No single existing dataset was provided with -d ...")
        exit()

    ds_id = byc["dataset_ids"][0]

    if not byc["args"].inputfile:
        print("No input file file specified (-i, --inputfile) => quitting ...")
        exit()

    inputfile = byc["args"].inputfile
    variants, fieldnames = read_tsv_to_dictlist(inputfile, int(byc["args"].limit))

    var_no = len(variants)
    up_v_no = 0

    delBiosVars = input("Delete variants from matched biosamples before insertion?\n(y|N): ")

    mongo_client = MongoClient( )
    var_coll = MongoClient( )[ ds_id ][ "variants" ]


    bios_ids = set()
    for c, v in enumerate(variants):
        bs_id = v.get("biosample_id", False)
        if not bs_id:
            print("¡¡¡ The `biosample_id` parameter is required for variant assignment !!!")
            exit()
        if not "pgxbs-" in bs_id:
            print("¡¡¡ The `biosample_id` parameter has to start with 'pgxbs-' !!!")
            exit()
        bios_ids.add(bs_id)

    print("=> The variants file contains {} variants from {} samples.".format(var_no, len(bios_ids)))
    proceed = input("Do you want to continue to update database **{}**?\n(Y|n): ".format(ds_id))
    if "n" in proceed.lower():
        exit()

    if "y" in delBiosVars.lower():
        for b_del in bios_ids:
            v_d = var_coll.delete_many({"biosample_id": b_del})
            print("==>> deleted {} variants from {}".format(v_d.deleted_count, b_del))

    v_proto = object_instance_from_schema_name(byc, "pgxVariant", "") #pgxVariant

    for c, v in enumerate(variants, 1):

        bs_id = v.get("biosample_id", False)

        # TODO: variant prototype from schema
        insert_v = v_proto.copy()
 
        # TODO: This is a bit of a double definition; disentangle ...
        insert_v.update( {
            "legacy_id": v.get("variant_id", f'pgxvar-{c:09d}'),
            "biosample_id": bs_id,            
            "callset_id": v.get("callset_id", re.sub("pgxbs-", "pgxcs-", bs_id)),
            "individual_id": v.get("individual_id", re.sub("pgxbs-", "pgxind-", bs_id))
        })

        insert_v = import_datatable_dict_line(byc, insert_v, fieldnames, v, "variant")
        insert_v.update({
            "variant_internal_id": variant_create_digest(insert_v, byc),
            "updated": datetime.datetime.now().isoformat()
        })

        if not byc["test_mode"]:
            vid = var_coll.insert_one( insert_v  ).inserted_id
            vstr = 'pgxvar-'+str(vid)
            var_coll.update_one({'_id':vid},{'$set':{ 'id':vstr }})
            print("=> inserted {}".format(vstr))
        else:
            prjsonnice(insert_v)

    exit()

################################################################################
################################################################################
################################################################################

if __name__ == '__main__':
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [-t TESTMODE]
#                              [--testModeCount TESTMODECOUNT]
#                              [--debugMode DEBUGMODE]
#                              [--filterPrecision FILTERPRECISION] [-l LIMIT]
#                              [--output OUTPUT] [-g GROUP_BY] [-p PARSE]
#                              [-m MODE] [-k KEY] [-u UPDATE] [-i INPUTFILE]
#                              [-o OUTPUTFILE] [-r RANDNO] [-s SOURCE]
#                              [-q QUERY] [-d DATASETIDS]
#                              [--requestEntityPathId REQUESTENTITYPATHID]
#                              [--requestedSchema REQUESTEDSCHEMA]
#                              [--filters FILTERS] [--assemblyId ASSEMBLYID]
#                              [--referenceName REFERENCENAME] [--start START]
#                              [--end END] [--variantType VARIANTTYPE]
#                              [--referenceBases REFERENCEBASES]
# ...
